# %%
using JuMP
using Gurobi

# %%
time_=8760
F=[0.03*2000*1000,0.03*950*1000,0.03*700*1000]
EA=[175.2252157*1000,85.60445144*1000,61.91153839*1000]
C=[1,1,1]
l=5000
H=[2.4,1.62,2.5]
P=[5,30,30]
# Out:
# 3-element Vector{Int64}:
#   5
#  30
#  30

# %%
using CSV
using DataFrames

df = CSV.read("data.csv", DataFrame)
D_t = df[!, "FR_load_forecast_entsoe_transparency"]
println(size(D_t))
# Out:
# (8760,)

# %%
model=Model(Gurobi.Optimizer)
@variable(model,0<=p[1:3,1:time_])
@variable(model,0<=k[1:3])
@variable(model,0<=d[1:time_])
@objective(model,Min,sum((F[g]+EA[g])*k[g]+sum(H[g]*P[g]*p[g,i] for i in 1:time_) for g in 1:3)-sum(l*d[i] for i in 1:time_))
@constraint(model,[g in 1:3,i in 1:time_],p[g,i] <= C[g]*k[g])
@constraint(model,[i in 1:time_],d[i] <= D_t[i])
@constraint(model,price[i in 1:time_],d[i]==sum(p[g,i] for g in 1:3))
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-31
# 8760-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  price[1] : -p[1,1] - p[2,1] - p[3,1] + d[1] == 0
#  price[2] : -p[1,2] - p[2,2] - p[3,2] + d[2] == 0
#  price[3] : -p[1,3] - p[2,3] - p[3,3] + d[3] == 0
#  price[4] : -p[1,4] - p[2,4] - p[3,4] + d[4] == 0
#  price[5] : -p[1,5] - p[2,5] - p[3,5] + d[5] == 0
#  price[6] : -p[1,6] - p[2,6] - p[3,6] + d[6] == 0
#  price[7] : -p[1,7] - p[2,7] - p[3,7] + d[7] == 0
#  price[8] : -p[1,8] - p[2,8] - p[3,8] + d[8] == 0
#  price[9] : -p[1,9] - p[2,9] - p[3,9] + d[9] == 0
#  price[10] : -p[1,10] - p[2,10] - p[3,10] + d[10] == 0
#  price[11] : -p[1,11] - p[2,11] - p[3,11] + d[11] == 0
#  price[12] : -p[1,12] - p[2,12] - p[3,12] + d[12] == 0
#  price[13] : -p[1,13] - p[2,13] - p[3,13] + d[13] == 0
#  ⋮
#  price[8749] : -p[1,8749] - p[2,8749] - p[3,8749] + d[8749] == 0
#  price[8750] : -p[1,8750] - p[2,8750] - p[3,8750] + d[8750] == 0
#  price[8751] : -p[1,8751] - p[2,8751] - p[3,8751] + d[8751] == 0
#  price[8752] : -p[1,8752] - p[2,8752] - p[3,8752] + d[8752] == 0
#  price[8753] : -p[1,8753] - p[2,8753] - p[3,8753] + d[8753] == 0
#  price[8754] : -p[1,8754] - p[2,8754] - p[3,8754] + d[8754] == 0
#  price[8755] : -p[1,8755] - p[2,8755] - p[3,8755] + d[8755] == 0
#  price[8756] : -p[1,8756] - p[2,8756] - p[3,8756] + d[8756] == 0
#  price[8757] : -p[1,8757] - p[2,8757] - p[3,8757] + d[8757] == 0
#  price[8758] : -p[1,8758] - p[2,8758] - p[3,8758] + d[8758] == 0
#  price[8759] : -p[1,8759] - p[2,8759] - p[3,8759] + d[8759] == 0
#  price[8760] : -p[1,8760] - p[2,8760] - p[3,8760] + d[8760] == 0

# %% [markdown]
# Question (i) : optimal installed capacity mix

# %%
optimize!(model)
println("Variables value:",JuMP.value.(k))
println("Objective value: ", objective_value(model))
# Out:
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10510U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 43800 rows, 35043 columns and 96360 nonzeros
# Model fingerprint: 0xcfb341a3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 2e+05]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+04, 1e+05]
# Presolve removed 8760 rows and 0 columns
# Presolve time: 0.17s
# Presolved: 35040 rows, 35043 columns, 87600 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 6.834e+03
#  Factor NZ  : 2.506e+04 (roughly 4 MB of memory)
#  Factor Ops : 1.435e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -3.25435279e+12 -3.39498793e+13  1.54e+04 3.14e+04  7.55e+09     0s
#    1  -1.98480975e+12 -1.18547877e+13  5.85e+00 5.59e+03  8.09e+08     0s
#    2  -2.19999088e+12 -2.45692192e+12  4.55e-12 4.01e-10  2.08e+07     0s
#
# Barrier performed 2 iterations in 0.32 seconds (0.06 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2151   -2.3364118e+12   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#        1 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.3594461e-11      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2174   -2.3364118e+12   0.000000e+00   0.000000e+00      0s
#
# Solved in 2174 iterations and 0.47 seconds (0.10 work units)
# Optimal objective -2.336411841e+12
#
# User-callback calls 138, time in user-callback 0.00 sec
# Variables value:[55800.0, 13200.0, 21450.0]
# Objective value: -2.336411841358467e12

# %%
prices=[-JuMP.dual(price[i]) for i in 1:time_]
println(prices)
# Out:
# [48.6, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 12.0, 48.6, 48.6, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 63.11305000384771, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 12.0, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 75.0, 75.0, 75.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12.0, 12.0, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 48.6, 12.0, 12 ...

# %% [markdown]
# Question (ii) : share of each technology in the effective production

# %%
p1=sum(JuMP.value.(p[1,t]) for t in 1:8760)
p2=sum(JuMP.value.(p[2,t]) for t in 1:8760)
p3=sum(JuMP.value.(p[3,t]) for t in 1:8760)
total=sum(JuMP.value.(d[t]) for t in 1:8760)
println("ptot : ",total)
println("p1 : ",p1)
println("p2 : ",p2)
println("p3 : ",p3)
println("share of p1 : ",p1/total)
println("share of p2 : ",p2/total)
println("share of p3 : ",p3/total)
# Out:
# ptot : 4.72002968e8
# p1 : 4.3547595e8
# p2 : 2.92589925e7
# p3 : 7.2680255e6
# share of p1 : 0.9226127366216053
# share of p2 : 0.06198900109458634
# share of p3 : 0.015398262283808351

# %% [markdown]
# Question (iii) : total production and investment cost

# %%
cost=sum((EA[g]+F[g])*JuMP.value.(k[g])+sum((H[g]*P[g])*JuMP.value.(p[g,i]) for i in 1:time_)  for g in 1:3)
# Out:
# 2.3602998641533497e10

# %%
benef = sum(sum(prices[i]*JuMP.value.(p[g,i]) for i in 1:time_) for g in 1:3)
# Out:
# 2.3602998641533318e10

# %%
benef-cost
# Out:
# -0.000179290771484375

# %% [markdown]
# Question (iv) : total CO2 emitted by your system

# %%
CO2=[1.4,0.5,0.6]
production=[p1,p2,p3]
emissions= sum(CO2[t]*production[t,1] for t in 1:3)
# Out:
# 6.2865664155e8

# %% [markdown]
# Question (v) :  amount of load curtailment

# %%
sum(max(0, D_t[t] - sum(JuMP.value(p[g, t]) for g in 1:3)) for t in 1:time_)
# Out:
# 32850.0

# %% [markdown]
# Question (vi) : total profit of each technology

# %%
profit=zeros(3,1)
for g in 1:3
    profit[g,1] =  -(EA[g]+F[g])*JuMP.value.(k[g]) -sum((H[g]*P[g]-prices[i])*JuMP.value.(p[g,i]) for i in 1:time_) 
end
println(profit[:,1])
# Out:
# [-0.000232696533203125, 5.054473876953125e-5, 0.0]

# %% [markdown]
# LCOE

# %%
LCOE=zeros(3,1)
for g in 1:3
    LCOE[g,1]=(((EA[g]+F[g])*JuMP.value.(k[g]))+(sum((H[g]*P[g])*JuMP.value.(p[g,i]) for i in 1:time_)))/production[g]
end
println(LCOE[:,1])
# Out:
# [42.14073919824963, 100.07746488564158, 319.69541259390184]
